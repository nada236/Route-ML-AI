# %%
class customer:
    def __init__ (self,name,age):
        self.name = name
        self.age = age
    
    def get_name(self):
        return self.name
    
    def get_age(self):
        return self.age
    
    def set_name(self):
        self.name = input("what's your name")

    def set_age(self):
        self.age = input("how old are you")

# %%
class Bike:
    def __init__(self, name, price):
        self.name = name
        self.price = price

    def get_name(self):
        return self.name
    
    def get_price(self):
        return self.price
    
    def set_name(self, bike_name):
        self.name = bike_name

    def set_price(self,bike_price):
        self.price = bike_price

class electricBike(Bike):
    def __init__(self, name, price, maxspeed):
        super().__init__(name,price)
        self.maxspeed = maxspeed
    
    def get_maxspeed(self):
        return self.maxspeed
    
    def set_maxspeed(self, bike_maxspeed):
        self.maxspeed = bike_maxspeed  


class normalBike(Bike):
    def __init__(self, name, price, maxspeed):
        super().__init__(name, price)
        self.maxspeed = maxspeed
    
    def get_maxspeed(self):
        return self.maxspeed
    
    def set_maxspeed(self, bike_maxspeed):
        self.maxspeed = bike_maxspeed

# %%
class MainBikeRental:
    def __init__(self):
        self.bikes = []
        self.rentals = []
        
    
    def get_bikes(self):
        return self.bikes
    
    def get_rentals(self):
        return self.rentals
    
    def set_bikes(self, new_bikes):
        self.bikes = new_bikes

    def set_rental(self,new_rentals):
        self.rentals = new_rentals

    def requestBike(self,num_of_bikes,age):
        self.num_of_bikes = num_of_bikes
        self.age = age
        if age < 6:
            print("customers must be over 6 years old to rent a bike")

        if num_of_bikes <= len(self.bikes) and age > 6:
            for b in range (num_of_bikes):
                self.bikes.pop(0)
        else:
            print("please wait 10 mins")
    
    def returnBike(self,rentalTime,num_of_bikes):
        for i in range(num_of_bikes):
            self.bike.append(Bike())
        bill_cost = rentalTime * 40 * num_of_bikes
        return bill_cost

    def addBike(self,new_bike):
        self.bikes.append(new_bike)

    def totalCost(self):
        total_cost = 0
        price = Bike.get_price()
        for P in len(price):
            total_cost += P
        return total_cost
